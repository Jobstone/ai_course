# %%
# %cd /content/drive/MyDrive/AI/wenda/wenda2
# !pip install -r requirements.txt

# %cd /content/drive/MyDrive/AI/wenda/ChatGLM-Efficient-Tuning
# !pip install -r requirements.txt

# %%
# %cd /content/drive/MyDrive/AI/wenda/ChatGLM-Efficient-Tuning
# !python src/infer.py --checkpoint_dir /content/drive/MyDrive/AI/wenda/ChatGLM-Efficient-Tuning/checkpoint4/checkpoint-5000
# --checkpoint_dir /content/drive/MyDrive/AI/wenda/ChatGLM-Efficient-Tuning/checkpoint2/checkpoint-4000
# !python src/infer.py

# %%
https://github.com/linhuall/ai_course.git

# %%
# %cd /content/drive/MyDrive/AI/wenda
# Out:
# /content/drive/MyDrive/AI/wenda

# %%
# !git add .
# !git commit -m "abc"

# %%
# !git remote add origin git@github.com:linhuall/ai_coz.git
# !git branch -M main
# !git push -u origin main
# Out:
# Uploading LFS objects: 100% (28/28), 624 MB | 0 B/s, done.
# Enumerating objects: 316, done.
# Counting objects: 100% (316/316), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (308/308), done.
# Writing objects: 100% (316/316), 1.21 GiB | 2.45 MiB/s, done.
# Total 316 (delta 93), reused 0 (delta 0)
# remote: Resolving deltas: 100% (93/93), done.
# remote: warning: File ChatGLM-Efficient-Tuning/tests/comparison_data_v2.json is 77.70 MB; this is larger than GitHub's recommended maximum file size of 50.00 MB
# remote: error: Trace: 76e563cb88ab1699c6941c88b48779aa95d38b474a5d22bf0f7609d167313050
# remote: error: See https://gh.io/lfs for more information.
# remote: error: File wenda2/memory/default/index.faiss is 287.46 MB; this exceeds GitHub's file size limit of 100.00 MB
# remote: error: GH001: Large files detected. You may want to try Git Large File Storage - https://git-lfs.github.com.
# To github.com:linhuall/ai_coz.git
# ...

# %%
# !git lfs install
# !git lfs track "*.bin" "*.faiss"
# !git add .gitattributes
# Out:
# Updated git hooks.
# Git LFS initialized.

# %%
# !git lfs untrack "*.psd"
# !git lfs untrack "*.bin" "*.faiss"
# %ls -la
# Out:
# total 30
# -rw------- 1 root root 4509 May 16 15:44 config.yml
# -rw------- 1 root root 4510 May 16 15:44 example.config.yml
# -rw------- 1 root root   19 May 16 15:44 .gitattributes
# -rw------- 1 root root    0 May 16 15:44 .gitignore
# -rw------- 1 root root    0 May 25 09:13 __init__.py
# drwx------ 3 root root 4096 Jun 12 10:42 memory/
# drwx------ 2 root root 4096 Jun 12 10:43 model/
# drwx------ 4 root root 4096 Jun 12 08:42 plugins/
# drwx------ 2 root root 4096 Jun 12 07:59 __pycache__/
# -rw------- 1 root root  214 May 16 15:44 requirements.txt
# drwx------ 2 root root 4096 May 16 15:48 txt/

# %%
# %cd /content/drive/MyDrive/AI/wenda
# Out:
# /content/drive/MyDrive/AI/wenda
